# %%
import pandas as pd

# %%
df=pd.read_csv("train.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# All the headings here which are the charactyeristics are called features. In this case, we want to predicts survived so survived is not a feature but a label/target

# %%
X=df.Age

# %%
X # feature metrix
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
y=df.Survived

# %%
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
X.shape
X.ndim # used to check the number of dimensions
# Out:
# (891,)

# %%
y.shape
# Out:
# (891,)

# %%
X=X.reshape(-1,1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-8396ba52baf5> in <module>
# ----> 1 X=X.reshape(-1,1)
#
# ~\miniconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'reshape'

# %%
X.isna().sum()
# Out:
# 177

# %%
X=X.fillna(method="ffill")

# %%
X.isna().sum()
# Out:
# 0

# %%
type(X)
# Out:
# pandas.core.series.Series

# %%
X=X.values

# %%
type(X)
# Out:
# numpy.ndarray

# %%
X=X.reshape(-1,1)

# %%
X
# Out:
# array([[22.  ],
#        [38.  ],
#        [26.  ],
#        [35.  ],
#        [35.  ],
#        [35.  ],
#        [54.  ],
#        [ 2.  ],
#        [27.  ],
#        [14.  ],
#        [ 4.  ],
#        [58.  ],
#        [20.  ],
#        [39.  ],
#        [14.  ],
#        [55.  ],
#        [ 2.  ],
#        [ 2.  ],
#        [31.  ],
#        [31.  ],
#        [35.  ],
#        [34.  ],
#        [15.  ],
#        [28.  ],
#        [ 8.  ],
#        [38.  ],
#        [38.  ],
#        [19.  ],
#        [19.  ],
#        [19.  ],
#        [40.  ],
#        [40.  ],
#        [40.  ],
#        [66.  ],
#        [28.  ],
#        [42.  ],
#        [42.  ],
#        [21.  ],
#        [18.  ],
#        [14.  ],
#        [40.  ],
#        [27.  ],
#        [27.  ],
#        [ 3.  ],
#        [19.  ],
#        [19.  ],
#        [19.  ],
#        [19.  ],
#        [19.  ],
#        [18.  ],
#        [ 7.  ],
#        [21.  ],
#        [49.  ],
#        [29.  ],
#        [65.  ],
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier
knn= KNeighborsClassifier()
knn
# Out:
# KNeighborsClassifier()

# %%
knn.fit(X,y)
# Out:
# KNeighborsClassifier()

# %%
knn.predict([[50]])
# Out:
# array([0], dtype=int64)

# %%
knn.predict([[70]])
# Out:
# array([0], dtype=int64)

# %%
knn.predict([[27]])
# Out:
# array([1], dtype=int64)

# %%
knn.score(X,y)
# Out:
# 0.6083052749719416
