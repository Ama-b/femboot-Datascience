# %%
import pandas as pd

# %%
import numpy as np

# %%
np.array([3,4,5,6])
# Out:
# array([3, 4, 5, 6])

# %%
pd.Series([3,4,5,6])
# Out:
# 0    3
# 1    4
# 2    5
# 3    6
# dtype: int64

# %%
pd.Series([[3,4,5,6],[4,5,5,6]])
# Out:
# 0    [3, 4, 5, 6]
# 1    [4, 5, 5, 6]
# dtype: object

# %%
pd.DataFrame([[3,4,5,6],[4,5,5,6]])
# Out:
#    0  1  2  3
# 0  3  4  5  6
# 1  4  5  5  6

# %%
pd.Series([[3,4,5,6],[4,5,5,6],[2,4,6,7]])
# Out:
# 0    [3, 4, 5, 6]
# 1    [4, 5, 5, 6]
# 2    [2, 4, 6, 7]
# dtype: object

# %%
df1=pd.DataFrame([[3,4,5,6],[4,5,5,6],[2,4,6,7]])

# %%
df1
# Out:
#    0  1  2  3
# 0  3  4  5  6
# 1  4  5  5  6
# 2  2  4  6  7

# %%
df1.index=[1,2,3]

# %%
df1
# Out:
#    0  1  2  3
# 1  3  4  5  6
# 2  4  5  5  6
# 3  2  4  6  7

# %%
df1.columns=["CSC210","CSC410","MCB202","BCH230"]

# %%
df1
# Out:
#    CSC210  CSC410  MCB202  BCH230
# 1       3       4       5       6
# 2       4       5       5       6
# 3       2       4       6       7

# %%
df1.index=["s1","s2","s3"]

# %%
df1
# Out:
#     CSC210  CSC410  MCB202  BCH230
# s1       3       4       5       6
# s2       4       5       5       6
# s3       2       4       6       7

# %% [markdown]
# ## Creating DataFrames from dictionaries

# %% [markdown]
# ### Review of dictionary

# %%
# [4,5,4,5]
# (4,5,4,5)
# List the difference between lists and tuples

ages={
    "Smith":23,
    "Mirablelle":45,
    "Faith":24,
    "Blessing":34,   
}

# %%
[
    3,
    5,
    6,
    7,
]
# Out:
# [3, 5, 6, 7]

# %%
type(ages)
# Out:
# dict

# %%
ages.keys()
# Out:
# dict_keys(['Smith', 'Mirablelle', 'Faith', 'Blessing'])

# %%
ages.values()
# Out:
# dict_values([23, 45, 24, 34])

# %%
df2=pd.DataFrame(ages,index=[1,2,3,4])

# %%
df2
# Out:
#    Smith  Mirablelle  Faith  Blessing
# 1     23          45     24        34
# 2     23          45     24        34
# 3     23          45     24        34
# 4     23          45     24        34

# %%
df2=pd.DataFrame(ages,index=[1])

# %%
df2
# Out:
#    Smith  Mirablelle  Faith  Blessing
# 1     23          45     24        34

# %%
import numpy as np
dict2={
    "country":["Nigeria","South Africa","Ghana"],
    "area":np.random.randint(2000,200000,3), 
    "population":np.random.randint(2000,200000,3)
}

# %%
dict2
# Out:
# {'country': ['Nigeria', 'South Africa', 'Ghana'],
#  'area': array([142080,  31482,  95707]),
#  'population': array([ 27625,  82515, 143956])}

# %%
pd.DataFrame(dict2,index=[1,2,3])
# Out:
#         country    area  population
# 1       Nigeria  142080       27625
# 2  South Africa   31482       82515
# 3         Ghana   95707      143956

# %% [markdown]
# ### Importing external data

# %%
data1=pd.read_csv("train.csv")

# %%
data1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data1.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
data1.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
data1.info
# Out:
# <bound method DataFrame.info of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
data1.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200
