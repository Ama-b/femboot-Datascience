# %%
import pandas as pd

# %%
df=pd.read_csv("../dataset/drinks.csv")

# %%
df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
df.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %%
df.plot(kind="box")

# %%
df["beer_servings"].max()
# Out:
# 376

# %%
df["beer_servings"]==df["beer_servings"].max()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 188    False
# 189    False
# 190    False
# 191    False
# 192    False
# Name: beer_servings, Length: 193, dtype: bool

# %%
df[df["beer_servings"]==df["beer_servings"].max()]
# Out:
#      country  beer_servings  spirit_servings  wine_servings  \
# 117  Namibia            376                3              1
#
#      total_litres_of_pure_alcohol continent
# 117                           6.8    Africa

# %%
df[df["beer_servings"]==df["beer_servings"].min()]
# Out:
#               country  beer_servings  spirit_servings  wine_servings  \
# 0         Afghanistan              0                0              0
# 13         Bangladesh              0                0              0
# 40       Cook Islands              0              254             74
# 46        North Korea              0                0              0
# 79               Iran              0                0              0
# 90             Kuwait              0                0              0
# 97              Libya              0                0              0
# 103          Maldives              0                0              0
# 106  Marshall Islands              0                0              0
# 107        Mauritania              0                0              0
# 111            Monaco              0                0              0
# 128          Pakistan              0                0              0
# 147        San Marino              0                0              0
# ...

# %%
df[df["beer_servings"]==df["beer_servings"].min()].shape
# Out:
# (15, 6)

# %%
df[df["beer_servings"]==df["beer_servings"].min()]
# Out:
#               country  beer_servings  spirit_servings  wine_servings  \
# 0         Afghanistan              0                0              0
# 13         Bangladesh              0                0              0
# 40       Cook Islands              0              254             74
# 46        North Korea              0                0              0
# 79               Iran              0                0              0
# 90             Kuwait              0                0              0
# 97              Libya              0                0              0
# 103          Maldives              0                0              0
# 106  Marshall Islands              0                0              0
# 107        Mauritania              0                0              0
# 111            Monaco              0                0              0
# 128          Pakistan              0                0              0
# 147        San Marino              0                0              0
# ...

# %%
df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
df.beer_servings.sort_values(ascending=False)
# Out:
# 117    376
# 45     361
# 62     347
# 65     346
# 135    343
#       ...
# 97       0
# 90       0
# 79       0
# 40       0
# 0        0
# Name: beer_servings, Length: 193, dtype: int64

# %%
df["total_consumption"]=df.beer_servings+df.spirit_servings+df.wine_servings+df.total_litres_of_pure_alcohol

# %%
df
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent  total+consumption  \
# 0                             0.0           Asia                0.0
# ...

# %%
df["total_consumption"].max()
# Out:
# 707.4

# %%
df.iloc[:,1:5].head()
# Out:
#    beer_servings  spirit_servings  wine_servings  total_litres_of_pure_alcohol
# 0              0                0              0                           0.0
# 1             89              132             54                           4.9
# 2             25                0             14                           0.7
# 3            245              138            312                          12.4
# 4            217               57             45                           5.9

# %%
df.iloc[:,1:5].sum()
# Out:
# beer_servings                   20489.0
# spirit_servings                 15632.0
# wine_servings                    9544.0
# total_litres_of_pure_alcohol      910.4
# dtype: float64

# %%
df.iloc[:,1:5].sum(axis=1)
# Out:
# 0        0.0
# 1      279.9
# 2       39.7
# 3      707.4
# 4      324.9
#        ...
# 188    443.7
# 189    116.0
# 190      6.1
# 191     57.5
# 192     90.7
# Length: 193, dtype: float64

# %%
import numpy as np

# %%
x=np.random.randint(12,40,(3,4))

# %%
x
# Out:
# array([[14, 20, 34, 35],
#        [21, 25, 34, 19],
#        [23, 20, 14, 23]])

# %%
x.sum()
# Out:
# 282

# %%
x.sum(axis=0)
# Out:
# array([58, 65, 82, 77])

# %%
x.sum(axis=1)
# Out:
# array([103,  99,  80])

# %%
df["mod_sum"]=df.iloc[:,1:5].sum(axis=1)

# %%
df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent  total+consumption  \
# 0                           0.0      Asia                0.0
# 1                           4.9    Europe              279.9
# 2                           0.7    Africa               39.7
# 3                          12.4    Europe              707.4
# 4                           5.9    Africa              324.9
#
#    total_consumption  mod_sum
# 0                0.0      0.0
# 1              279.9    279.9
# 2               39.7     39.7
# 3              707.4    707.4
# 4              324.9    324.9

# %%
df.drop(["mod_sum"],axis=1,inplace=True)

# %%
df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent  total+consumption  \
# 0                           0.0      Asia                0.0
# 1                           4.9    Europe              279.9
# 2                           0.7    Africa               39.7
# 3                          12.4    Europe              707.4
# 4                           5.9    Africa              324.9
#
#    total_consumption
# 0                0.0
# 1              279.9
# 2               39.7
# 3              707.4
# 4              324.9

# %%
df.total_consumption==df.total_consumption.max()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 188    True
# 189    True
# 190    True
# 191    True
# 192    True
# Name: total_consumption, Length: 193, dtype: bool

# %%
df[df.total_consumption==df.total_consumption.max()]
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent  total+consumption  \
# 0                             0.0           Asia                0.0
# ...

# %%
df.total_consumption.max()
# Out:
# 707.4

# %%
df[df.total_consumption==df.total_consumption.max()]
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent  total+consumption  \
# 0                             0.0           Asia                0.0
# ...

# %%
df[df.total_consumption==df.total_consumption.min()]
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent  total+consumption  \
# 0                             0.0           Asia                0.0
# ...

# %%
df.total_consumption==df.total_consumption.min()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 188    True
# 189    True
# 190    True
# 191    True
# 192    True
# Name: total_consumption, Length: 193, dtype: bool

# %% [markdown]
# ## Assignment

# %%
df
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent  total+consumption  \
# 0                             0.0           Asia                0.0
# ...
