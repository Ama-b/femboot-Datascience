# %% [markdown]
# ## $$ y=x^3 + sin(x) $$

# %%
import numpy as np
import math

# %%
np.random.seed(10)
x=np.random.rand(20)

# %%
x=np.array(x)

# %%
x_sin=np.sin(x)

# %%
x_sin
# Out:
# array([0.69708274, 0.02075046, 0.5920887 , 0.68076309, 0.47811478,
#        0.22290813, 0.19677044, 0.68930603, 0.16830594, 0.08822496,
#        0.63295162, 0.81538467, 0.00394826, 0.49008936, 0.72609183,
#        0.57493612, 0.66070331, 0.28774945, 0.79425117, 0.65529703])

# %%
y=[]
def y_value(x):
    y.append(x**3 + np.sin(x));
y_value(x)

# %%
y
# Out:
# [array([1.15596879, 0.0207594 , 0.84650486, 1.10062286, 0.60199838,
#         0.2342679 , 0.20454023, 1.12920229, 0.17314225, 0.08891436,
#         0.95487752, 1.68198001, 0.00394832, 0.62445834, 1.26270838,
#         0.80474866, 1.03668784, 0.31261485, 1.56730088, 1.02017269])]

# %%
y=np.array(y)

# %%
y
# Out:
# array([[1.15596879, 0.0207594 , 0.84650486, 1.10062286, 0.60199838,
#         0.2342679 , 0.20454023, 1.12920229, 0.17314225, 0.08891436,
#         0.95487752, 1.68198001, 0.00394832, 0.62445834, 1.26270838,
#         0.80474866, 1.03668784, 0.31261485, 1.56730088, 1.02017269]])

# %%
y=y.reshape(20)

# %%
plt.plot(x,y)
