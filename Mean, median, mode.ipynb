# %%
def mean():
    pass

# %%
mean()

# %%
def mean():
    sum_of_numbers=0
    for i in range(4):
        numbers= float(input("Enter a number: "))
        sum_of_numbers=sum_of_numbers+numbers
    return sum_of_numbers/4

# %%
mean()
# Out:
# Enter a number: 10
# Enter a number: 25
# Enter a number: 20
# Enter a number: 40
# 23.75

# %%
def mean(n):
    sum_of_numbers=0
    for i in range(n):
        numbers= float(input("Enter a number: "))
        sum_of_numbers=sum_of_numbers+numbers
    return sum_of_numbers/n

# %%
mean(2)
# Out:
# Enter a number: 23
# Enter a number: 14
# 18.5

# %%
def factorial(n):
    fact=1
    for i in range(1,n+1):
        fact=fact*i
    return fact

# %%
factorial(6)
# Out:
# 720

# %%
def even(n):
    list=[]
    for i in range(n):
        entered=float(input("Enter the list of nubers: "))
        if entered%2==0:
            list.append(entered)
    return list

# %%
even(5)
# Out:
# Enter the list of nubers: 34
# Enter the list of nubers: 56
# Enter the list of nubers: 78
# Enter the list of nubers: 67
# Enter the list of nubers: 59
# [34.0, 56.0, 78.0]

# %%
def median(n):
    list=[]
    for i in range(n):
        middle=float(input("Enter the list of nubers: "))
        list.append(middle)
    list.sort()
    pos=int((n-1)/2)
    print(list[pos])

# %%
median(5)
# Out:
# Enter the list of nubers: 15
# Enter the list of nubers: 12
# Enter the list of nubers: 13
# Enter the list of nubers: 89
# Enter the list of nubers: 43
# 15.0

# %%
def median(n):
    list=[]
    for i in range(n):
        middle=float(input("Enter the list of nubers: "))
        list.append(middle)
    list.sort()
    if n%2==0:
        pos1=n/2
        pos2=pos1-1
        return int(list[pos1]+list[pos2])/2
    else:
        pos=n//2
        return list[pos]

# %%
median(4)
# Out:
# Enter the list of nubers: 12
# Enter the list of nubers: 32
# Enter the list of nubers: 23
# Enter the list of nubers: 43
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-4589182aef28> in <module>
# ----> 1 median(4)
#
# <ipython-input-8-5ddd4a846dfa> in median(n)
#       8         pos1=n/2
#       9         pos2=pos1-1
# ---> 10         return int(list[pos1]+list[pos2])/2
#      11     else:
#      12         pos=n//2
#
# TypeError: list indices must be integers or slices, not float
